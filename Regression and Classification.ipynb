# %% [markdown]
# # Data-X Spring 2019: Homework 05
#
# ### Linear regression & Logistic regression
#
#
#
# ## Name: PoojaRao
#
# ## SID: 3034312272
#
#
#
#
# In this homework, you will do some exercises on prediction using sklearn.
#
# REMEMBER TO DISPLAY ALL OUTPUTS. If the question asks you to do something, make sure to print your results.

# %% [markdown]
# ## Part 1 - Regression

# %% [markdown]
# ### Data:
# __Data Source__:
# Data file is uploaded to bCourses and is named: __Energy.csv__
# (Link in the Assignment details page on Bcourses)
#
# The dataset was created by Angeliki Xifara ( Civil/Structural Engineer) and was processed by Athanasios Tsanas, Oxford Centre for Industrial and Applied Mathematics, University of Oxford, UK).
#
# __Data Description__:
#
# The dataset contains eight attributes of a building (or features, denoted by X1...X8) and response being the heating load on the building, y1.
#
# * X1	Relative Compactness
# * X2	Surface Area
# * X3	Wall Area
# *  X4	Roof Area
# *  X5	Overall Height
# * X6	Orientation
# *  X7	Glazing Area
# *  X8	Glazing Area Distribution
# *  y1	Heating Load

# %% [markdown]
# #### Q1.1
# Read the data file from the csv.
#
# Print the count of NaN values for each attribute in the dataset.
#
# Print the Range (min, max) and percentiles (25th, 50th, and 75th) of each attribute in the dataset

# %%
# your code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Energy.csv')
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84
# 5    0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.46
# 6    0.90  563.5  318.5  122.50  7.0   4  0.0   0  20.71
# 7    0.90  563.5  318.5  122.50  7.0   5  0.0   0  19.68
# 8    0.86  588.0  294.0  147.00  7.0   2  0.0   0  19.50
# 9    0.86  588.0  294.0  147.00  7.0   3  0.0   0  19.95
# 10   0.86  588.0  294.0  147.00  7.0   4  0.0   0  19.34
# 11   0.86  588.0  294.0  147.00  7.0   5  0.0   0  18.31
# 12   0.82  612.5  318.5  147.00  7.0   2  0.0   0  17.05
# 13   0.82  612.5  318.5  147.00  7.0   3  0.0   0  17.41
# 14   0.82  612.5  318.5  147.00  7.0   4  0.0   0  16.95
# 15   0.82  612.5  318.5  147.00  7.0   5  0.0   0  15.98
# 16   0.79  637.0  343.0  147.00  7.0   2  0.0   0  28.52
# 17   0.79  637.0  343.0  147.00  7.0   3  0.0   0  29.90
# 18   0.79  637.0  343.0  147.00  7.0   4  0.0   0  29.63
# 19   0.79  637.0  343.0  147.00  7.0   5  0.0   0  28.75
# 20   0.76  661.5  416.5  122.50  7.0   2  0.0   0  24.77
# 21   0.76  661.5  416.5  122.50  7.0   3  0.0   0  23.93
# 22   0.76  661.5  416.5  122.50  7.0   4  0.0   0  24.77
# 23   0.76  661.5  416.5  122.50  7.0   5  0.0   0  23.93
# 24   0.74  686.0  245.0  220.50  3.5   2  0.0   0   6.07
# 25   0.74  686.0  245.0  220.50  3.5   3  0.0   0   6.05
# 26   0.74  686.0  245.0  220.50  3.5   4  0.0   0   6.01
# 27   0.74  686.0  245.0  220.50  3.5   5  0.0   0   6.04
# 28   0.71  710.5  269.5  220.50  3.5   2  0.0   0   6.37
# 29   0.71  710.5  269.5  220.50  3.5   3  0.0   0   6.40
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...
# 738  0.79  637.0  343.0  147.00  7.0   4  0.4   5  41.09
# 739  0.79  637.0  343.0  147.00  7.0   5  0.4   5  40.79
# 740  0.76  661.5  416.5  122.50  7.0   2  0.4   5  38.82
# 741  0.76  661.5  416.5  122.50  7.0   3  0.4   5  39.72
# 742  0.76  661.5  416.5  122.50  7.0   4  0.4   5  39.31
# 743  0.76  661.5  416.5  122.50  7.0   5  0.4   5  39.86
# 744  0.74  686.0  245.0  220.50  3.5   2  0.4   5  14.41
# 745  0.74  686.0  245.0  220.50  3.5   3  0.4   5  14.19
# 746  0.74  686.0  245.0  220.50  3.5   4  0.4   5  14.17
# 747  0.74  686.0  245.0  220.50  3.5   5  0.4   5  14.39
# 748  0.71  710.5  269.5  220.50  3.5   2  0.4   5  12.43
# 749  0.71  710.5  269.5  220.50  3.5   3  0.4   5  12.63
# 750  0.71  710.5  269.5  220.50  3.5   4  0.4   5  12.76
# 751  0.71  710.5  269.5  220.50  3.5   5  0.4   5  12.42
# 752  0.69  735.0  294.0  220.50  3.5   2  0.4   5  14.12
# 753  0.69  735.0  294.0  220.50  3.5   3  0.4   5  14.28
# 754  0.69  735.0  294.0  220.50  3.5   4  0.4   5  14.37
# 755  0.69  735.0  294.0  220.50  3.5   5  0.4   5  14.21
# 756  0.66  759.5  318.5  220.50  3.5   2  0.4   5  14.96
# 757  0.66  759.5  318.5  220.50  3.5   3  0.4   5  14.92
# 758  0.66  759.5  318.5  220.50  3.5   4  0.4   5  14.92
# 759  0.66  759.5  318.5  220.50  3.5   5  0.4   5  15.16
# 760  0.64  784.0  343.0  220.50  3.5   2  0.4   5  17.69
# 761  0.64  784.0  343.0  220.50  3.5   3  0.4   5  18.19
# 762  0.64  784.0  343.0  220.50  3.5   4  0.4   5  18.16
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64
#
# [768 rows x 9 columns]

# %%
print('Count of NaN values')
df.isnull().sum()
# Out:
# Count of NaN values
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# dtype: int64

# %%
attributes = ['X1','X2','X3','X4','X5','X6','X7','X8','Y1']
print('Range (min, max)')
for i in attributes:
    min_df = df[i].min() 
    max_df =  df[i].max()
    print('%s = (%s, %s)'%(i, min_df, max_df))
# Out:
# Range (min, max)
# X1 = (0.62, 0.98)
# X2 = (514.5, 808.5)
# X3 = (245.0, 416.5)
# X4 = (110.25, 220.5)
# X5 = (3.5, 7.0)
# X6 = (2, 5)
# X7 = (0.0, 0.4)
# X8 = (0, 5)
# Y1 = (6.01, 43.1)

# %%
attributes = ['X1','X2','X3','X4','X5','X6','X7','X8','Y1']
print('Percentiles (25th, 50th, 75th)')
for i in attributes:
    per_25 = np.percentile(df[i], 25)
    per_50 = np.percentile(df[i], 50)
    per_75 = np.percentile(df[i], 75)
    print('%s = (%s, %s, %s)'%(i, per_25, per_50, per_75))
# Out:
# Percentiles (25th, 50th, 75th)
# X1 = (0.6825, 0.75, 0.83)
# X2 = (606.375, 673.75, 741.125)
# X3 = (294.0, 318.5, 343.0)
# X4 = (140.875, 183.75, 220.5)
# X5 = (3.5, 5.25, 7.0)
# X6 = (2.75, 3.5, 4.25)
# X7 = (0.1, 0.25, 0.4)
# X8 = (1.75, 3.0, 4.0)
# Y1 = (12.9925, 18.95, 31.6675)

# %% [markdown]
#  __REGRESSION__:
#
# Using the data, we want to predict "Heating load". The output variable is continuous. Hence, we need to use a regression algorithm.
#
# __Q 1.2:__
#
# Split the dataset randomly into train and test. Train a **Linear Regression** model on 80% of the data (80-20 split).
# What is the intercept and coefficient values?

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split 

x=df.iloc[:,0:8] 
y=df.iloc[:,8]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

logreg = linear_model.LinearRegression() 
logreg.fit(x_train, y_train)
y_predicted = logreg.predict(x_train) 
print('Coefficients:', logreg.coef_) 
print('Intercept:', logreg.intercept_)
# Out:
# Coefficients: [-6.33926290e+01 -5.86380428e-02  3.46024305e-02 -4.66202367e-02
#   4.36194652e+00  1.81224259e-02  1.98760201e+01  2.19167208e-01]
# Intercept: 79.13116174147392

# %% [markdown]
# #### Q.1.3:
#
# Create a function which takes arrays of prediction and actual values of the output as parameters to calculate **'Root Mean Square error'** (RMSE) metric:
#
# 1. Use the function to calculate the training RMSE
# 2. Use the function to calculate the test RMSE

# %%
# your code
print("Mean squared error for training data:",np.sqrt(np.mean((y_predicted - y_train) ** 2)))
# Out:
# Mean squared error for training data: 2.9242420751260143

# %%
logreg.fit(x_test, y_test)
y_predicted_test = logreg.predict(x_test) 
RMSE_test = np.sqrt(np.mean((y_predicted_test - y_test) ** 2))
print("Mean squared error for test data:", RMSE_test)
# Out:
# Mean squared error for test data: 2.868627719618982

# %% [markdown]
# #### Q1.4:
#
# Let's see the effect of amount of data on the performance of prediction model. Use varying amounts of data (100,200,300,400,500,all) from the training data you used previously to train different regression models. Report  training error and test error in each case. Test data  is the same as above for  all  these cases.
#
# **Plot error rates vs number of training examples.** Both the training error and the test error should be plotted. Comment on the relationship you observe between the amount of data used to train the model and the test accuracy of the model.
#
# __Hint:__ Use array indexing to choose varying data amounts

# %%
# your code
data = [100, 200, 300, 400, 500, x_train.shape[0]]
RMSE_train = np.array([]) 
for values in data:
    x_sample = x_train.sample(values) 
    x_index = x_sample.index
    y_sample = y_train.loc[list(x_index)]
    logreg.fit(x_sample, y_sample) 
    y_predicted = logreg.predict(x_sample)
    RMSE_values = (np.sqrt(np.mean((y_predicted - y_sample)**2)))
    RMSE_train = np.append(RMSE_train, RMSE_values)
print(RMSE_train)
RMSE_test = np.ones(len(data))*RMSE_test
f, ax = plt.subplots()
ax.plot(data, RMSE_train, label = 'Training Set RMSE') 
ax.plot(data, RMSE_test, label = 'Test Set RMSE') 
ax.legend()
ax.set_xlabel('Amount of Data') 
ax.set_ylabel('RMSE')
# Out:
# [3.08265798 2.87736228 2.97293944 2.97599556 2.92838127 2.92424208]
# Text(0, 0.5, 'RMSE')

# %% [markdown]
# ## Part 2 - Classification

# %% [markdown]
# __CLASSIFICATION__:
# LABELS ARE DISCRETE VALUES.
#
# Here the model is trained to classify each instance into a set of predefined discrete classes. On inputting a feature vector into the model, the trained model is able to predict a class of that instance.
#
#
# #### Q2.1
# Bucket the values of 'y1' i.e 'Heating Load'  from the original dataset into 3 classes:
#
# 0: 'Low' ( < 14),
# 1: 'Medium'  (14-28),
# 2: 'High'  (>28)
#
# **HINT:** Use pandas.cut
#
# This converts the given dataset  into a classification problem. Use this dataset with transformed 'heating load' to create a **logistic regression** classifiction model that predicts heating load type of a building. Split the data randomly into training and test set. Train the model on 80% of the data (80-20 split).

# %%
# your code
df['Classes']= pd.cut(df['Y1'],bins = [df['Y1'].min(), 14, 28, df['Y1'].max()+1] ,labels =['Low', 'Medium','High'], right = False)
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1 Classes
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  Medium
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  Medium
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  Medium
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  Medium
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  Medium
# 5    0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.46  Medium
# 6    0.90  563.5  318.5  122.50  7.0   4  0.0   0  20.71  Medium
# 7    0.90  563.5  318.5  122.50  7.0   5  0.0   0  19.68  Medium
# 8    0.86  588.0  294.0  147.00  7.0   2  0.0   0  19.50  Medium
# 9    0.86  588.0  294.0  147.00  7.0   3  0.0   0  19.95  Medium
# 10   0.86  588.0  294.0  147.00  7.0   4  0.0   0  19.34  Medium
# 11   0.86  588.0  294.0  147.00  7.0   5  0.0   0  18.31  Medium
# 12   0.82  612.5  318.5  147.00  7.0   2  0.0   0  17.05  Medium
# 13   0.82  612.5  318.5  147.00  7.0   3  0.0   0  17.41  Medium
# 14   0.82  612.5  318.5  147.00  7.0   4  0.0   0  16.95  Medium
# 15   0.82  612.5  318.5  147.00  7.0   5  0.0   0  15.98  Medium
# 16   0.79  637.0  343.0  147.00  7.0   2  0.0   0  28.52    High
# 17   0.79  637.0  343.0  147.00  7.0   3  0.0   0  29.90    High
# 18   0.79  637.0  343.0  147.00  7.0   4  0.0   0  29.63    High
# 19   0.79  637.0  343.0  147.00  7.0   5  0.0   0  28.75    High
# 20   0.76  661.5  416.5  122.50  7.0   2  0.0   0  24.77  Medium
# 21   0.76  661.5  416.5  122.50  7.0   3  0.0   0  23.93  Medium
# 22   0.76  661.5  416.5  122.50  7.0   4  0.0   0  24.77  Medium
# 23   0.76  661.5  416.5  122.50  7.0   5  0.0   0  23.93  Medium
# 24   0.74  686.0  245.0  220.50  3.5   2  0.0   0   6.07     Low
# 25   0.74  686.0  245.0  220.50  3.5   3  0.0   0   6.05     Low
# 26   0.74  686.0  245.0  220.50  3.5   4  0.0   0   6.01     Low
# 27   0.74  686.0  245.0  220.50  3.5   5  0.0   0   6.04     Low
# 28   0.71  710.5  269.5  220.50  3.5   2  0.0   0   6.37     Low
# 29   0.71  710.5  269.5  220.50  3.5   3  0.0   0   6.40     Low
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...     ...
# 738  0.79  637.0  343.0  147.00  7.0   4  0.4   5  41.09    High
# 739  0.79  637.0  343.0  147.00  7.0   5  0.4   5  40.79    High
# 740  0.76  661.5  416.5  122.50  7.0   2  0.4   5  38.82    High
# 741  0.76  661.5  416.5  122.50  7.0   3  0.4   5  39.72    High
# 742  0.76  661.5  416.5  122.50  7.0   4  0.4   5  39.31    High
# 743  0.76  661.5  416.5  122.50  7.0   5  0.4   5  39.86    High
# 744  0.74  686.0  245.0  220.50  3.5   2  0.4   5  14.41  Medium
# 745  0.74  686.0  245.0  220.50  3.5   3  0.4   5  14.19  Medium
# 746  0.74  686.0  245.0  220.50  3.5   4  0.4   5  14.17  Medium
# 747  0.74  686.0  245.0  220.50  3.5   5  0.4   5  14.39  Medium
# 748  0.71  710.5  269.5  220.50  3.5   2  0.4   5  12.43     Low
# 749  0.71  710.5  269.5  220.50  3.5   3  0.4   5  12.63     Low
# 750  0.71  710.5  269.5  220.50  3.5   4  0.4   5  12.76     Low
# 751  0.71  710.5  269.5  220.50  3.5   5  0.4   5  12.42     Low
# 752  0.69  735.0  294.0  220.50  3.5   2  0.4   5  14.12  Medium
# 753  0.69  735.0  294.0  220.50  3.5   3  0.4   5  14.28  Medium
# 754  0.69  735.0  294.0  220.50  3.5   4  0.4   5  14.37  Medium
# 755  0.69  735.0  294.0  220.50  3.5   5  0.4   5  14.21  Medium
# 756  0.66  759.5  318.5  220.50  3.5   2  0.4   5  14.96  Medium
# 757  0.66  759.5  318.5  220.50  3.5   3  0.4   5  14.92  Medium
# 758  0.66  759.5  318.5  220.50  3.5   4  0.4   5  14.92  Medium
# 759  0.66  759.5  318.5  220.50  3.5   5  0.4   5  15.16  Medium
# 760  0.64  784.0  343.0  220.50  3.5   2  0.4   5  17.69  Medium
# 761  0.64  784.0  343.0  220.50  3.5   3  0.4   5  18.19  Medium
# 762  0.64  784.0  343.0  220.50  3.5   4  0.4   5  18.16  Medium
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  Medium
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  Medium
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  Medium
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  Medium
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  Medium
#
# [768 rows x 10 columns]

# %% [markdown]
# #### Q2.2
# - Print the training and test accuracies
# - Print the confusion matrix
# - Print the precision and recall numbers for all the classes

# %%
# your code
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
x1 = df.iloc[:,0:8]
y1 = df.iloc[:,9]

x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.2, random_state=100)
logreg = linear_model.LogisticRegression() 
logreg.fit(x_train1, y_train1)

training_accuracy=logreg.score(x_train1, y_train1) 
print('Training accuracy:', training_accuracy)
test_accuracy=logreg.score(x_test1, y_test1) 
print('Test accuracy:', test_accuracy)

y_pred1 = logreg.predict(x_test1) 
ConfusionMatrix=pd.DataFrame(confusion_matrix(y_test1, y_pred1),columns=['Predicted High','Predicted Medium','Predicted Low'],index=['Actual High','Actual Low','Actual Medium'])
print('Confusion matrix of test data is: \n',ConfusionMatrix)
                             
print('Precision:', precision_score(y_test1, y_pred1, average= None) )
print('Recall:', precision_score(y_test1, y_pred1, average= None) )
# Out:
# Training accuracy: 0.8061889250814332
# Test accuracy: 0.7727272727272727
# Confusion matrix of test data is:
#                 Predicted High  Predicted Medium  Predicted Low
# Actual High                55                 0              0
# Actual Low                  0                42              1
# Actual Medium              25                 9             22
# Precision: [0.6875     0.82352941 0.95652174]
# Recall: [0.6875     0.82352941 0.95652174]
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# #### Q2.3
# ##### K Fold Cross Validation
#
#  In k-fold cross-validation, the shuffled training data is partitioned into k disjoint sets and the model is trained on k −1 sets and validated on the kth set. This process is repeated k times with each set chosen as the validation set once. The cross-validation accuracy is reported as the average accuracy of the k iterations
#
# __Use 7-fold cross validation on the training data. Print the average accuracy__

# %%
# your code
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kf = KFold(n_splits = 7)
kf.get_n_splits(x_train1)

logreg = linear_model.LogisticRegression(solver = 'lbfgs') 
scores = cross_val_score(logreg, x_train1, y_train1, cv = kf, n_jobs = -1, scoring = 'accuracy')

print('Average Accuracy', scores.mean())
# Out:
# Average Accuracy 0.7817211524108076

# %% [markdown]
# __Q2.4__
#
# One of the preprocessing steps in Data science is Feature Scaling i.e getting all our data on the same scale by setting same  Min-Max of feature values.
# This makes training less sensitive to the scale of features .
# Scaling is important in algorithms that use distance functions as a part of classification. If we Scale features in the range [0,1] it is called unity based normalization.
#
# __Perform unity based normalization on the above dataset and train the model again, compare model performance in training and validation with your previous model.__
#
# refer:http://scikit-learn.org/stable/modules/preprocessing.html#preprocessing-scaler
# more at: https://en.wikipedia.org/wiki/Feature_scaling

# %%
# your code
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler() 
x_train_minmax = min_max_scaler.fit_transform(x_train1) 
x_test_minmax = min_max_scaler.fit_transform(x_test1)

logreg.fit(x_train_minmax, y_train1)

training_accuracy = logreg.score(x_train_minmax,y_train1) 
test_accuracy = logreg.score(x_test_minmax,y_test1) 

y_pred1 = logreg.predict(x_test_minmax) 
ConfusionMatrix=pd.DataFrame(confusion_matrix(y_test1, y_pred1),columns=['Predicted High','Predicted Medium','Predicted Low'],index=['Actual 0','Actual 1','Actual 2'])
print ('Confusion matrix of test data is: \n',ConfusionMatrix,'\n')
print('Precision:', precision_score(y_test1, y_pred1, average = None ) )
print('Recall:', precision_score(y_test1, y_pred1, average = None ) )
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Users\Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Confusion matrix of test data is:
#            Predicted High  Predicted Medium  Predicted Low
# Actual 0              54                 0              1
# Actual 1               0                40              3
# Actual 2              24                 2             30
#
# Precision: [0.69230769 0.95238095 0.88235294]
# Recall: [0.69230769 0.95238095 0.88235294]
